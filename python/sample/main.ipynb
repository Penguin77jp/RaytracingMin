# %%
import numpy as np
import matplotlib.pyplot as plt
from LensSystem import LensSystem, Ray

# %%
lsys = LensSystem('simple.csv')
print(lsys)
# Out:
#     r   h   d  ior
# 0  50  20  10  1.5
# 1 -50  20  50  1.0

# %%
rays = lsys.raytrace_from_object(Ray(np.array([0, 1, -1000]), np.array([0, 0, 1])))
rays
# Out:
# [origin: [    0     1 -1000], direction: [0 0 1],
#  origin: [  0.         1.       -59.989999], direction: [-0.         -0.00666756  0.99997777],
#  origin: [  0.           0.93344775 -50.00871401], direction: [ 0.         -0.01934031  0.99981296]]

# %%
# 像面との交点
t = -rays[-1].origin[2] / rays[-1].direction[2]
p = rays[-1].position(t)
print(p)
# Out:
# [ 0.         -0.03391713  0.        ]

# %%
lsys.plot()
# Out:
# <AxesSubplot:xlabel='$z \\mathrm{[mm]}$', ylabel='$y \\mathrm{[mm]}$'>

# %%
lsys.optical_path_diagram()
# Out:
# <AxesSubplot:xlabel='$z \\mathrm{[mm]}$', ylabel='$y \\mathrm{[mm]}$'>
